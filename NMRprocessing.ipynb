# %%
# Install required packages
#!pip install nmrpy numpy matplotlib pandas

# Import required libraries
#import nmrpy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import display

# Set up matplotlib for inline plotting in Jupyter
# %matplotlib inline
#Having both inline and widget can cause issues, so we will use only one of them.
#%matplotlib widget

# %%
# The data is stored in a binary file called 1r in the pdata/1 folder.
# We can load this data using numpy
# Load the 1r file as a binary file and convert to numpy array
with open("/Users/bbbartel/ASU Dropbox/BioProteanLab/NMR/NMR Data/Organoids/DiffMedia/bodm_w1_con/10/pdata/1/1r", 'rb') as f:
    data = np.fromfile(f, dtype=np.int32)
    
# Print basic information about the loaded data
print(f"Data shape: {data.shape}")
print(f"Data type: {data.dtype}")
print(f"Data: {data}")
# Out:
# Data shape: (32768,)
# Data type: int32
# Data: [-37810 -10542   8656 ...     94 -18636 -30109]

# %%
# Generate 10 random numbers
random_data = np.random.rand(10)

# Plot the random data
plt.plot(random_data, marker='o')
plt.title("Test Plot of Random Data")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot(data)
plt.show()
plt.close('all')
